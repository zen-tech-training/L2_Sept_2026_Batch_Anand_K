# %%
import ollama
from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv

env_path = find_dotenv()
if not env_path:
    raise FileNotFoundError(".env file not found.")

load_dotenv(env_path)
apiKey = os.getenv("OPENAI_API_KEY")
hfApiKey = os.getenv("HF_API_KEY")

# %%
response = ollama.chat(
    model="gpt-oss:120b-cloud",
    messages=[
        {"role": "user", "content": "Which is the capital city of India?"}
    ]
)
print(type(response))
print(response['message']['content'])

# %%
import os
from dotenv import load_dotenv, find_dotenv

env_path = find_dotenv()
if not env_path:
    raise FileNotFoundError("Could not find .env file. Please ensure it exists in the project directory.")

load_dotenv(env_path)
openai_api_key = os.getenv("OPENAI_API_KEY")
print(f'OpenAI API Key: {openai_api_key}')

client = OpenAI(api_key=openai_api_key)
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Which is the capital city of India?"}
    ]
)
print(type(response))
print(response.choices[0].message.content)

# %%
from transformers import pipeline
from huggingface_hub import InferenceClient

sentiment_analyzer = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst2')
prompt = 'Explain the need of Langchain'
response = sentiment_analyzer(prompt)
print(response)
print(type(response))

# %%
hf_client = InferenceClient(token=hfApiKey)
response = hf_client.chat.completions.create(
    model="distilbert-base-uncased-finetuned-sst2",
    messages=[
        {"role": "user", "content": "Which is the capital city of India?"}
    ]
)
print(type(response))
print(response)
